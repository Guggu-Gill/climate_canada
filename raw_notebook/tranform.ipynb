# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# !ls ../data
# Out:
# Daily_ARMSTRONG (AUT)_3987.csv   Daily_HAINES JUNCTION_1556.csv
# Daily_CAPE PARRY A_1633.csv      Daily_HOPEDALE (AUT)_6781.csv
# Daily_COLD LAKE A_2832.csv       Daily_PILOT MOUND (AUT)_3649.csv
# Daily_COMOX A_155.csv            Daily_TRENTON A_5126.csv
# Daily_GREENWOOD A_6354.csv

# %%
files=os.listdir("../data/")
# Out:
# 9

# %%
df_0=pd.read_csv("../data/"+files[0])
df_1=pd.read_csv("../data/"+files[1])
df_2=pd.read_csv("../data/"+files[2])

df_3=pd.read_csv("../data/"+files[3])
df_4=pd.read_csv("../data/"+files[4])
df_5=pd.read_csv("../data/"+files[5])

df_6=pd.read_csv("../data/"+files[6])
df_7=pd.read_csv("../data/"+files[7])
df_8=pd.read_csv("../data/"+files[8])

print(df_0.shape[0]+df_1.shape[0]+df_2.shape[0]+df_3.shape[0]+df_4.shape[0]+df_5.shape[0]+df_6.shape[0]+df_7.shape[0]+df_8.shape[0])
# Out:
# 206413

# %%
df=pd.concat([df_0, df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8], ignore_index=True)

# %%
df.head()
# Out:
#    Longitude (x)  Latitude (y)     Station Name  Climate ID   Date/Time  Year  \
# 0        -137.58         60.77  HAINES JUNCTION     2100630  2023-01-01  2023
# 1        -137.58         60.77  HAINES JUNCTION     2100630  2023-01-02  2023
# 2        -137.58         60.77  HAINES JUNCTION     2100630  2023-01-03  2023
# 3        -137.58         60.77  HAINES JUNCTION     2100630  2023-01-04  2023
# 4        -137.58         60.77  HAINES JUNCTION     2100630  2023-01-05  2023
#
#    Month  Day  Data Quality  Max Temp (°C)  ... Total Snow (cm)  \
# 0      1    1           NaN           -5.8  ...             NaN
# 1      1    2           NaN            1.4  ...             NaN
# 2      1    3           NaN           -2.6  ...             NaN
# 3      1    4           NaN          -12.0  ...             NaN
# 4      1    5           NaN          -10.6  ...             NaN
#
#    Total Snow Flag Total Precip (mm)  Total Precip Flag Snow on Grnd (cm)  \
# ...

# %%
df.shape
# Out:
# (206413, 31)

# %%
df.head()
# Out:
#    Longitude (x)  Latitude (y)     Station Name  Climate ID   Date/Time  Year  \
# 0        -137.58         60.77  HAINES JUNCTION     2100630  2023-01-01  2023
# 1        -137.58         60.77  HAINES JUNCTION     2100630  2023-01-02  2023
# 2        -137.58         60.77  HAINES JUNCTION     2100630  2023-01-03  2023
# 3        -137.58         60.77  HAINES JUNCTION     2100630  2023-01-04  2023
# 4        -137.58         60.77  HAINES JUNCTION     2100630  2023-01-05  2023
#
#    Month  Day  Data Quality  Max Temp (°C)  ... Total Snow (cm)  \
# 0      1    1           NaN           -5.8  ...             NaN
# 1      1    2           NaN            1.4  ...             NaN
# 2      1    3           NaN           -2.6  ...             NaN
# 3      1    4           NaN          -12.0  ...             NaN
# 4      1    5           NaN          -10.6  ...             NaN
#
#    Total Snow Flag Total Precip (mm)  Total Precip Flag Snow on Grnd (cm)  \
# ...

# %%
df.describe()
# Out:
#        Longitude (x)   Latitude (y)    Climate ID           Year  \
# count  206413.000000  206413.000000  2.064130e+05  206413.000000
# mean      -98.177507      52.856096  4.693558e+06    1988.400837
# std        25.951702       7.741770  2.603567e+06      20.643684
# min      -137.580000      44.120000  1.021830e+06    1953.000000
# 25%      -124.720000      49.190000  2.200675e+06    1970.000000
# 50%       -98.900000      50.290000  5.022125e+06    1987.000000
# 75%       -77.530000      55.450000  6.158875e+06    2007.000000
# max       -60.220000      70.170000  8.502400e+06    2023.000000
#
#                Month            Day  Max Temp (°C)  Min Temp (°C)  \
# count  206413.000000  206413.000000  206413.000000  206412.000000
# mean        6.510913      15.728753       6.833737      -3.133274
# std         3.453046       8.797863      13.966484      13.145253
# min         1.000000       1.000000     -47.800000     -53.900000
# ...

# %%
df.nunique()
# Out:
# Longitude (x)                    9
# Latitude (y)                     9
# Station Name                     9
# Climate ID                       9
# Date/Time                    25932
# Year                            71
# Month                           12
# Day                             31
# Data Quality                     0
# Max Temp (°C)                  782
# Max Temp Flag                    1
# Min Temp (°C)                  724
# Min Temp Flag                    2
# Mean Temp (°C)                 746
# Mean Temp Flag                   1
# Heat Deg Days (°C)             634
# Heat Deg Days Flag               1
# Cool Deg Days (°C)             113
# Cool Deg Days Flag               1
# Total Rain (mm)                575
# Total Rain Flag                  5
# Total Snow (cm)                323
# Total Snow Flag                  5
# Total Precip (mm)              605
# Total Precip Flag                6
# Snow on Grnd (cm)              253
# Snow on Grnd Flag                3
# ...

# %%
df.isna().sum()
# Out:
# Longitude (x)             0
# Latitude (y)              0
# Station Name              0
# Climate ID                0
# Date/Time                 0
# Year                      0
# Month                     0
# Day                       0
# Max Temp (°C)             0
# Min Temp (°C)             1
# Mean Temp (°C)            0
# Heat Deg Days (°C)        0
# Cool Deg Days (°C)        0
# Total Rain (mm)       45349
# Total Snow (cm)       45641
# Total Precip (mm)     25293
# Snow on Grnd (cm)     50310
# dtype: int64

# %%
feat_to_keep=["Longitude (x)","Latitude (y)","Station Name","Climate ID","Date/Time","Year","Month","Day","Max Temp (°C)","Min Temp (°C)","Mean Temp (°C)","Heat Deg Days (°C)","Cool Deg Days (°C)","Total Rain (mm)","Total Snow (cm)","Total Precip (mm)","Snow on Grnd (cm)"]

# %%
df=df[feat_to_keep]

# %%
df.isna().sum()
# Out:
# Longitude (x)             0
# Latitude (y)              0
# Station Name              0
# Climate ID                0
# Date/Time                 0
# Year                      0
# Month                     0
# Day                       0
# Max Temp (°C)             0
# Min Temp (°C)             1
# Mean Temp (°C)            0
# Heat Deg Days (°C)        0
# Cool Deg Days (°C)        0
# Total Rain (mm)       45349
# Total Snow (cm)       45641
# Total Precip (mm)     25293
# Snow on Grnd (cm)     50310
# dtype: int64

# %%
df=df.dropna(subset=["Min Temp (°C)"], axis=0)

# %%
df.isna().sum()
# Out:
# Longitude (x)             0
# Latitude (y)              0
# Station Name              0
# Climate ID                0
# Date/Time                 0
# Year                      0
# Month                     0
# Day                       0
# Max Temp (°C)             0
# Min Temp (°C)             0
# Mean Temp (°C)            0
# Heat Deg Days (°C)        0
# Cool Deg Days (°C)        0
# Total Rain (mm)       45348
# Total Snow (cm)       45641
# Total Precip (mm)     25293
# Snow on Grnd (cm)     50310
# dtype: int64

# %%
df_na=df.dropna()

# %%
df_na.shape
# Out:
# (147843, 17)

# %%
pd.set_option('display.max_rows', None)
station_year_counts = df_na[["Year", "Station Name"]].value_counts()
station_year_counts = station_year_counts.sort_index(level=["Station Name", "Year"])

# %%
station_year_counts
# Out:
# Year  Station Name
# 1955  ARMSTRONG (AUT)      365
# 1956  ARMSTRONG (AUT)      366
# 1957  ARMSTRONG (AUT)      365
# 1958  ARMSTRONG (AUT)      365
# 1959  ARMSTRONG (AUT)      335
# 1960  ARMSTRONG (AUT)      366
# 1961  ARMSTRONG (AUT)      365
# 1962  ARMSTRONG (AUT)      365
# 1963  ARMSTRONG (AUT)      365
# 1964  ARMSTRONG (AUT)      366
# 1965  ARMSTRONG (AUT)      365
# 1966  ARMSTRONG (AUT)      365
# 1967  ARMSTRONG (AUT)      365
# 1968  ARMSTRONG (AUT)      366
# 1969  ARMSTRONG (AUT)      365
# 1970  ARMSTRONG (AUT)      365
# 1971  ARMSTRONG (AUT)      365
# 1972  ARMSTRONG (AUT)      366
# 1973  ARMSTRONG (AUT)      365
# 1974  ARMSTRONG (AUT)      365
# 1975  ARMSTRONG (AUT)      365
# 1976  ARMSTRONG (AUT)      366
# 1977  ARMSTRONG (AUT)      365
# 1978  ARMSTRONG (AUT)      365
# 1979  ARMSTRONG (AUT)      365
# 1980  ARMSTRONG (AUT)      366
# 1981  ARMSTRONG (AUT)      365
# 1982  ARMSTRONG (AUT)      364
# 1995  ARMSTRONG (AUT)        2
# ...

# %%
df_na["Station Name"].value_counts()
# Out:
# COLD LAKE A          23926
# GREENWOOD A          23629
# TRENTON A            23392
# COMOX A              23109
# CAPE PARRY A         12902
# PILOT MOUND (AUT)    12641
# HOPEDALE (AUT)       10762
# ARMSTRONG (AUT)      10198
# HAINES JUNCTION       7284
# Name: Station Name, dtype: int64

# %%
df_na.shape
# Out:
# (147843, 17)

# %%
pd.set_option('display.min_rows', 10)

df_na.head()
# Out:
#       Longitude (x)  Latitude (y)     Station Name  Climate ID   Date/Time  \
# 9883        -137.58         60.77  HAINES JUNCTION     2100630  1993-03-08
# 9887        -137.58         60.77  HAINES JUNCTION     2100630  1993-03-15
# 9896        -137.58         60.77  HAINES JUNCTION     2100630  1993-03-29
# 9898        -137.58         60.77  HAINES JUNCTION     2100630  1993-03-31
# 9950        -137.58         60.77  HAINES JUNCTION     2100630  1993-06-01
#
#       Year  Month  Day  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  \
# 9883  1993      3    8            0.0          -18.0            -9.0
# 9887  1993      3   15           -6.0          -27.0           -16.5
# 9896  1993      3   29            6.0          -18.0            -6.0
# 9898  1993      3   31            8.0          -13.0            -2.5
# 9950  1993      6    1           21.5            1.0            11.3
#
#       Heat Deg Days (°C)  Cool Deg Days (°C)  Total Rain (mm)  \
# ...

# %%
df_na[["Station Name","Longitude (x)","Latitude (y)"]].value_counts()
# Out:
# Station Name       Longitude (x)  Latitude (y)
# COLD LAKE A        -110.28        54.42           23926
# GREENWOOD A        -64.92         44.98           23629
# TRENTON A          -77.53         44.12           23392
# COMOX A            -124.90        49.72           23109
# CAPE PARRY A       -124.72        70.17           12902
# PILOT MOUND (AUT)  -98.90         49.19           12641
# HOPEDALE (AUT)     -60.22         55.45           10762
# ARMSTRONG (AUT)    -88.91         50.29           10198
# HAINES JUNCTION    -137.58        60.77            7284
# dtype: int64
